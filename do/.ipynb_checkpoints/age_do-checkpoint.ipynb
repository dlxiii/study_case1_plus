# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt

#sns.set(font="Times New Roman")

pd.set_option("display.max_columns", 144)

# %%
data = pd.read_csv('./data.csv',names=['Lon.','Lat.','DO','Age','Time'],
                   header=None,index_col=False,na_values='Inf')

# %%
data.head()
# Out:
#          Lon.       Lat.   DO        Age        Time
# 0  140.073333  35.565000  2.3  49.919295  2014/07/01
# 1  139.843889  35.650556  3.6   1.034096  2014/07/01
# 2  140.019167  35.540556  1.0  62.429709  2014/07/01
# 3  139.905556  35.554444  0.1  75.370811  2014/07/01
# 4  139.946667  35.535000  2.8  71.681776  2014/07/01

# %%
sns.pairplot(data[['Lat.','Lon.','DO','Age','Time']])

# %%
sns.scatterplot(data=data, x="Age", y="DO", hue="Time",style="Time")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='DO'>

# %%
sns.relplot(
    data=data, x="Age", y="DO",
    col="Time", hue="Time",
    kind="scatter")

# %%
plt.clf()
plt.figure(figsize=(6,6))
g = sns.relplot(
    data=data, x="Age", y="DO",
    col="Time", hue="Time",
    kind="scatter")
sns.set(font_scale=1.3)

# %%
plt.clf()
plt.figure(figsize=(6,6))
#sns.set(font="Times New Roman")
g = sns.jointplot(data=data[data.Time=='2014/07/01'], 
                  x="Age", y="DO",
                  kind="reg",
                  xlim = (0,95),ylim = (0,15))
#xrange = [35.25,35.68]
#yrange1 = [xrange[0] * slope1 + intercept1, xrange[1] * slope1 + intercept1]
#g.ax_joint.plot(xrange, yrange1, 'b-', linewidth = 2)
#yrange2 = [xrange[0] * slope2 + intercept2, xrange[1] * slope2 + intercept2]
#g.ax_joint.plot(xrange, yrange2, c = 'orange', linewidth = 2)
sns.set(font_scale=1.3)
g.set_axis_labels("Bottom river water age (Day)","Bottom DO (mg/L)")
plt.savefig("joint_do_age_20140701",dpi=300)
plt.show()

# %%
plt.clf()
plt.figure(figsize=(6,6))
#sns.set(font="Times New Roman")
g = sns.jointplot(data=data[data.Time=='2014/10/01'], 
                  x="Age", y="DO",
                  kind="reg",
                  xlim = (0,95),ylim = (0,15))
#xrange = [35.25,35.68]
#yrange1 = [xrange[0] * slope1 + intercept1, xrange[1] * slope1 + intercept1]
#g.ax_joint.plot(xrange, yrange1, 'b-', linewidth = 2)
#yrange2 = [xrange[0] * slope2 + intercept2, xrange[1] * slope2 + intercept2]
#g.ax_joint.plot(xrange, yrange2, c = 'orange', linewidth = 2)
sns.set(font_scale=1.3)
g.set_axis_labels("Bottom river water age (Day)","Bottom DO (mg/L)")
plt.savefig("joint_do_age_20141001",dpi=300)
plt.show()

# %%
plt.clf()
plt.figure(figsize=(6,6))
#sns.set(font="Times New Roman")
g = sns.jointplot(data=data[data.Time=='2015/06/01'], 
                  x="Age", y="DO",
                  kind="reg",
                  xlim = (0,95),ylim = (0,15))
#xrange = [35.25,35.68]
#yrange1 = [xrange[0] * slope1 + intercept1, xrange[1] * slope1 + intercept1]
#g.ax_joint.plot(xrange, yrange1, 'b-', linewidth = 2)
#yrange2 = [xrange[0] * slope2 + intercept2, xrange[1] * slope2 + intercept2]
#g.ax_joint.plot(xrange, yrange2, c = 'orange', linewidth = 2)
sns.set(font_scale=1.3)
g.set_axis_labels("Bottom river water age (Day)","Bottom DO (mg/L)")
plt.savefig("joint_do_age_20150601",dpi=300)
plt.show()

# %%
plt.clf()
plt.figure(figsize=(6,6))
g = sns.relplot(
    data=data, x="Age", y="DO",
    kind="scatter")
sns.set(font_scale=1.3)

# %%
sns.regplot(data=data, x="Age", y="DO",x_estimator=np.mean)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='DO'>
